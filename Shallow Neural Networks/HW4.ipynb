# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Load the dataset
data = pd.read_csv('41-50.csv')

# Separate features (citations columns)
X = data[['cit_2017', 'cit_2018', 'cit_2019', 'cit_2020', 'cit_2021']]
y = data['cit_2022']

# Normalize the input features
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# %%
# Build the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(3, activation='relu', input_shape=(5,)),  # Hidden layer with 3 nodes
    tf.keras.layers.Dense(1, activation='linear')  # Output layer with 1 node
])

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),  loss='mean_absolute_error', metrics=['mae'])

# Train the model
model.fit(X_train, y_train, epochs=1000, batch_size=32, validation_data=(X_test, y_test))

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model on the test data
mae = model.evaluate(X_test, y_test, verbose=0)
print(f'Mean Absolute Error on the Test Data: {mae[0]}')
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 654.9713 - mae: 654.9713 - val_loss: 375.2130 - val_mae: 375.2130
# Epoch 2/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 654.9056 - mae: 654.9056 - val_loss: 375.1720 - val_mae: 375.1720
# Epoch 3/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 654.8436 - mae: 654.8436 - val_loss: 375.1307 - val_mae: 375.1307
# Epoch 4/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 654.7800 - mae: 654.7800 - val_loss: 375.0885 - val_mae: 375.0885
# Epoch 5/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 654.7139 - mae: 654.7139 - val_loss: 375.0461 - val_mae: 375.0461
# Epoch 6/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 654.6488 - mae: 654.6488 - val_loss: 375.0046 - val_mae: 375.0046
# Epoch 7/1000
# ...
